# %%
import numpy as np

# %%
my_video_dataset = np.random.rand(10, 30, 3, 224, 224)
my_video_dataset
# Out:
# array([[[[[7.72309665e-01, 6.10129250e-01, 9.44442387e-01, ...,
#            4.14815534e-01, 1.48886965e-01, 5.24007753e-01],
#           [5.04120664e-01, 5.30770455e-02, 5.76285981e-01, ...,
#            5.67881549e-01, 5.71973761e-01, 3.21465525e-01],
#           [2.48477129e-02, 8.55094038e-01, 6.62094392e-01, ...,
#            3.93956590e-01, 5.83109973e-01, 2.28794489e-01],
#           ...,
#           [9.65534960e-01, 3.27926935e-01, 1.96056759e-01, ...,
#            3.04009914e-01, 5.14550967e-01, 6.95938397e-01],
#           [2.03478607e-01, 2.67152078e-01, 4.78932768e-01, ...,
#            1.95434627e-01, 4.71368290e-01, 9.27877306e-01],
#           [3.13290892e-01, 5.05402211e-01, 9.18078707e-01, ...,
#            4.66665921e-01, 6.90855435e-01, 9.19920847e-02]],
#
#          [[7.11274273e-03, 4.22343445e-01, 7.23748717e-01, ...,
#            5.18996723e-01, 8.58723051e-01, 8.40130210e-01],
#           [4.44338360e-02, 8.09689982e-01, 5.74262532e-01, ...,
# ...

# %%
my_video_dataset[2,:,2,:,:].mean()
#number 2 sorrelates with the color blue
# third dimension relates with the color
# Out:
# np.float64(0.5001204727556537)

# %%
max_value = 0
max_index = 0
for cur_video in range(10):
    cur_value = my_video_dataset[cur_video, cur_frame, 2, :, :].mean()
    if cur_value > max_value:
        max_value = cur_value
        max_index = (cur_video, cur_frame)
print(max_value, max_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 max_index = 0
#       3 for cur_video in range(10):
# ----> 4     cur_value = my_video_dataset[cur_video, cur_frame, 2, :, :].mean()
#       5     if cur_value > max_value:
#       6         max_value = cur_value
#
# NameError: name 'cur_frame' is not defined

# %%
my_blue_dimension_video_dataset.shape

# %%
my_blue_dimension_video_dataset = my_video_dataset[:,:,2,:,:].mean()
my_blue_dimension_video_dataset.mean((1, 2, 3)).argmax()
#mean of the blue dimension of the video dataset
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 my_blue_dimension_video_dataset = my_video_dataset[:,:,2,:,:].mean()
# ----> 2 my_blue_dimension_video_dataset.mean((1, 2, 3)).argmax()
#       3 #mean of the blue dimension of the video dataset
#
# File ~/Dev/AWS/LearnNumpy/venv/lib/python3.12/site-packages/numpy/_core/_methods.py:124, in _mean(a, axis, dtype, out, keepdims, where)
#     120 arr = asanyarray(a)
#     122 is_float16_result = False
# --> 124 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     125 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     126     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File ~/Dev/AWS/LearnNumpy/venv/lib/python3.12/site-packages/numpy/_core/_methods.py:87, in _count_reduce_items(arr, axis, keepdims, where)
#      85     items = 1
# ...

# %%
print(my_video_dataset.shape)
my_video_dataset_transposed = my_video_dataset.transpose(1, 0, 2, 3, 4)
# transposing means changing the order of the dimensions
print(my_video_dataset_transposed.shape)

# %% [markdown]
# Broadcasting

# %%
my_color_manipulation_arr = np.array([1,1,2])

# %%
my_video_dataset_transposed*my_color_manipulation_arr

# %%
import numpy as np

# %%
my_arr = np.linspace(0,1,20)
#linspace creates an array of numbers between 0 and 1 with 20 elements

# %%
my_arr[my_arr>0.5]= -999

# %%
my_range[my_range==5] = -999

# %%
np.random.seed(0)
